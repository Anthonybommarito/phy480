# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt('eigen_basis.dat')
data1=np.loadtxt('eigen_basis1.dat')
data2=np.loadtxt('eigen_basis2.dat')
data3=np.loadtxt('eigen_basis3.dat')
data4=np.loadtxt('eigen_basis4.dat')
data5=np.loadtxt('eigen_basis5.dat')
data6=np.loadtxt('eigen_basis6.dat')
data7=np.loadtxt('eigen_basis7.dat')

# %%
plt.plot(data[:,0],data[:,1],label='dim=1')
plt.plot(data1[:,0],data1[:,1],label='dim=5')
plt.plot(data2[:,0],data2[:,1],label='dim=10')
plt.plot(data3[:,0],data3[:,1],label='dim=20')
r=np.linspace(0,15)
y=2*r*np.exp(-r)
#plt.plot(r,y,label='ground state eigenfunction')
plt.legend()
plt.title(r'$\psi (r)$ vs r b=1.8')
plt.xlabel('r')
plt.ylabel(r'$\psi (r)$',fontsize=15)
# Out:
# Text(0,0.5,'$\\psi (r)$')

# %%
plt.plot(data4[:,0],data4[:,1],label='dim=1')
plt.plot(data5[:,0],data5[:,1],label='dim=5')
plt.plot(data6[:,0],data6[:,1],label='dim=10')
plt.plot(data7[:,0],data7[:,1],label='dim=20')
plt.title( r'$\psi (r)$ vs r for b=2.8')
plt.legend()
plt.xlabel('r')
plt.ylabel(r'$\psi (r)$',fontsize=15)
# Out:
# Text(0,0.5,'$\\psi (r)$')
